# %%
import geopandas as gpd
import pandas as pd

# %%
kochi_ku = gpd.read_file('N03-23_39_230101.geojson')

# %%
kochi_ku.plot()
# Out:
# <Axes: >

# %%
kochi_ku.head()
# Out:
#   N03_001  N03_002 N03_003 N03_004 N03_007
# 0     高知県      NaN     NaN     高知市   39201  \
# 1     高知県      NaN     NaN     高知市   39201
# 2     高知県      NaN     NaN     高知市   39201
# 3     高知県      NaN     NaN     高知市   39201
# 4     高知県      NaN     NaN     高知市   39201
#
#                                             geometry
# 0  POLYGON ((133.50242 33.46526, 133.50238 33.465...
# 1  POLYGON ((133.50307 33.46582, 133.50301 33.465...
# 2  POLYGON ((133.50352 33.46594, 133.50350 33.465...
# 3  POLYGON ((133.50372 33.46595, 133.50369 33.465...
# 4  POLYGON ((133.50348 33.46610, 133.50346 33.466...

# %%
kochi_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   4494 non-null   object
#  1   N03_002   0 non-null      float64
#  2   N03_003   1871 non-null   object
#  3   N03_004   4494 non-null   object
#  4   N03_007   4494 non-null   object
#  5   geometry  4494 non-null   geometry
# dtypes: float64(1), geometry(1), object(4)
# memory usage: 210.8+ KB

# %%
kochi_pop = pd.read_csv('kochi.csv')

# %%
kochi_pop.head()
# Out:
#       KEY_CODE  HYOSYO CITYNAME   NAME    人口総数       男       女    世帯総数
# 0        39201       1      高知市    NaN  326545  152455  174090  154171
# 1    392010010       3      高知市     上町    3037    1321    1716    1654
# 2  39201001001       4      高知市  上町一丁目     952     410     542     430
# 3  39201001002       4      高知市  上町二丁目     457     211     246     299
# 4  39201001003       4      高知市  上町三丁目     764     325     439     435

# %%
kochi_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2450 entries, 0 to 2449
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  2450 non-null   int64
#  1   HYOSYO    2450 non-null   int64
#  2   CITYNAME  2450 non-null   object
#  3   NAME      2415 non-null   object
#  4   人口総数      2450 non-null   object
#  5   男         2450 non-null   object
#  6   女         2450 non-null   object
#  7   世帯総数      2450 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 153.3+ KB

# %%
kochi_ku.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
kochi_ku
# Out:
#      N03_001  N03_002 N03_003 N03_004 KEY_CODE
# 0        高知県      NaN     NaN     高知市    39201  \
# 1        高知県      NaN     NaN     高知市    39201
# 2        高知県      NaN     NaN     高知市    39201
# 3        高知県      NaN     NaN     高知市    39201
# 4        高知県      NaN     NaN     高知市    39201
# ...      ...      ...     ...     ...      ...
# 4489     高知県      NaN     幡多郡     黒潮町    39428
# 4490     高知県      NaN     幡多郡     黒潮町    39428
# 4491     高知県      NaN     幡多郡     黒潮町    39428
# 4492     高知県      NaN     幡多郡     黒潮町    39428
# 4493     高知県      NaN     幡多郡     黒潮町    39428
#
#                                                geometry
# 0     POLYGON ((133.50242 33.46526, 133.50238 33.465...
# 1     POLYGON ((133.50307 33.46582, 133.50301 33.465...
# 2     POLYGON ((133.50352 33.46594, 133.50350 33.465...
# 3     POLYGON ((133.50372 33.46595, 133.50369 33.465...
# 4     POLYGON ((133.50348 33.46610, 133.50346 33.466...
# ...                                                 ...
# ...

# %%
kochi_ku['KEY_CODE'] = kochi_ku['KEY_CODE'].astype(int)

# %%
kochi_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   4494 non-null   object
#  1   N03_002   0 non-null      float64
#  2   N03_003   1871 non-null   object
#  3   N03_004   4494 non-null   object
#  4   KEY_CODE  4494 non-null   int64
#  5   geometry  4494 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), object(3)
# memory usage: 210.8+ KB

# %%
kochi_ku_pop = kochi_ku.merge(kochi_pop,on='KEY_CODE')

# %%
kochi_ku_pop
# Out:
#      N03_001  N03_002 N03_003 N03_004  KEY_CODE
# 0        高知県      NaN     NaN     高知市     39201  \
# 1        高知県      NaN     NaN     高知市     39201
# 2        高知県      NaN     NaN     高知市     39201
# 3        高知県      NaN     NaN     高知市     39201
# 4        高知県      NaN     NaN     高知市     39201
# ...      ...      ...     ...     ...       ...
# 4489     高知県      NaN     幡多郡     黒潮町     39428
# 4490     高知県      NaN     幡多郡     黒潮町     39428
# 4491     高知県      NaN     幡多郡     黒潮町     39428
# 4492     高知県      NaN     幡多郡     黒潮町     39428
# 4493     高知県      NaN     幡多郡     黒潮町     39428
#
#                                                geometry  HYOSYO CITYNAME NAME
# 0     POLYGON ((133.50242 33.46526, 133.50238 33.465...       1      高知市  NaN  \
# 1     POLYGON ((133.50307 33.46582, 133.50301 33.465...       1      高知市  NaN
# 2     POLYGON ((133.50352 33.46594, 133.50350 33.465...       1      高知市  NaN
# ...

# %%
kochi_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   4494 non-null   object
#  1   N03_002   0 non-null      float64
#  2   N03_003   1871 non-null   object
#  3   N03_004   4494 non-null   object
#  4   KEY_CODE  4494 non-null   int64
#  5   geometry  4494 non-null   geometry
#  6   HYOSYO    4494 non-null   int64
#  7   CITYNAME  4494 non-null   object
#  8   NAME      0 non-null      object
#  9   人口総数      4494 non-null   object
#  10  男         4494 non-null   object
#  11  女         4494 non-null   object
#  12  世帯総数      4494 non-null   object
# dtypes: float64(1), geometry(1), int64(2), object(9)
# memory usage: 456.6+ KB

# %%
kochi_ku_pop['人口総数'] = kochi_ku_pop['人口総数'].astype(int)

# %%
kochi_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   4494 non-null   object
#  1   N03_002   0 non-null      float64
#  2   N03_003   1871 non-null   object
#  3   N03_004   4494 non-null   object
#  4   KEY_CODE  4494 non-null   int64
#  5   geometry  4494 non-null   geometry
#  6   HYOSYO    4494 non-null   int64
#  7   CITYNAME  4494 non-null   object
#  8   NAME      0 non-null      object
#  9   人口総数      4494 non-null   int64
#  10  男         4494 non-null   object
#  11  女         4494 non-null   object
#  12  世帯総数      4494 non-null   object
# dtypes: float64(1), geometry(1), int64(3), object(8)
# memory usage: 456.6+ KB

# %%
kochi_ku_pop.plot(column='人口総数',legend=True)
# Out:
# <Axes: >

# %% [markdown]
# 高校3年は高知で住みました。高知は千葉と比べると、人は少ないで、小さい町です。でも、綺麗なところです。すぐに太平洋が見れます。食べ物も美味しいです。
